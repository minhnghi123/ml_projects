# %% [markdown]
# ## Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [1,2,3,4]
plt.plot(x,y,color='blue') ;  #[<matplotlib.lines.Line2D at 0x187ce8ee990>]

# %% [markdown]
# # Pyplot API

# %%
x =  np.linspace(0,10.1000)

# %%
plt.plot(x,np.sin(x),color='blue',linestyle='dashed',label='sin(x)') ; 
plt.plot(x,np.cos(x),color='red',label='cos(x)')
plt.title('Sinx and Cosx')
plt.xlabel('x values')
plt.ylabel( 'F(x)' )
# plt.xlim([0,4])
# plt.ylim([-0.75,0.75])
plt.legend()
